# %% [markdown]
# # March Madness 2019

# %% [markdown]
# ## Data Science Club
#
# #### Data from Kaggle Competition, site: https://www.kaggle.com/c/mens-machine-learning-competition-2019
# #### There are many datasets in this challenge (about 20 total), so it is useful to do some exploration before jumping into any major analyses

# %%
import pandas as pd
Event = pd.read_csv("/Users/ericenglin/Desktop/Data Science Club/DataFiles/PlayByPlay_2010/Events_2010.csv")

# %%
import matplotlib.style as style
pd.options.display.max_columns = None

# %%
import pandas as pd
from dplython import (DplyFrame, X, select, sift, sample_n,
    sample_frac, head, arrange, mutate, group_by, summarize)

# %%
# Then, cast the data frame to become a DplyFrame using the DplyFrame() function
Event = DplyFrame(Event)

# %%
Event.head()
# Out:
#    EventID  Season  DayNum  WTeamID  LTeamID  WPoints  LPoints  \
# 0        1    2010       7     1143     1293        0        0
# 1        2    2010       7     1143     1293        0        0
# 2        3    2010       7     1143     1293        0        0
# 3        4    2010       7     1143     1293        0        0
# 4        5    2010       7     1143     1293        0        0
#
#    ElapsedSeconds  EventTeamID  EventPlayerID  EventType
# 0               0         1143         600578     sub_in
# 1               0         1143         600584     sub_in
# 2               0         1143         600585     sub_in
# 3              10         1143         600581  miss2_lay
# 4              10         1143         600581    reb_off

# %%
Event.shape
# Out:
# (2502630, 11)

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 15]

Event.groupby("EventType").size().plot(kind='barh')

# %%
Event.head(15)
# Out:
#     EventID  Season  DayNum  WTeamID  LTeamID  WPoints  LPoints  \
# 0         1    2010       7     1143     1293        0        0
# 1         2    2010       7     1143     1293        0        0
# 2         3    2010       7     1143     1293        0        0
# 3         4    2010       7     1143     1293        0        0
# 4         5    2010       7     1143     1293        0        0
# 5         6    2010       7     1143     1293        2        0
# 6         7    2010       7     1143     1293        0        0
# 7         8    2010       7     1143     1293        0        0
# 8         9    2010       7     1143     1293        2        2
# 9        10    2010       7     1143     1293        0        0
# 10       11    2010       7     1143     1293        4        2
# 11       12    2010       7     1143     1293        0        0
# 12       13    2010       7     1143     1293        4        5
# 13       14    2010       7     1143     1293        0        0
# 14       15    2010       7     1143     1293        0        0
#
#     ElapsedSeconds  EventTeamID  EventPlayerID   EventType
# 0                0         1143         600578      sub_in
# 1                0         1143         600584      sub_in
# 2                0         1143         600585      sub_in
# 3               10         1143         600581   miss2_lay
# 4               10         1143         600581     reb_off
# 5               14         1143         600581  made2_jump
# 6               36         1293         602791  miss2_jump
# 7               36         1293         602781     reb_off
# 8               40         1293         602781  made2_jump
# 9               56         1143         600577      assist
# 10              56         1143         600581  made2_jump
# 11              72         1293         602791      assist
# 12              72         1293         602787  made3_jump
# 13              90         1293         602787       block
# 14              90         1143         600580  miss2_jump

# %%
NonEvent = ['sub_in', 'sub_out','timeout','timeout_tv','miss1_free','made1_free']

# %%
New_Event = Event[~Event.EventType.isin(NonEvent)]
New_Event.head()
# Out:
#    EventID  Season  DayNum  WTeamID  LTeamID  WPoints  LPoints  \
# 3        4    2010       7     1143     1293        0        0
# 4        5    2010       7     1143     1293        0        0
# 5        6    2010       7     1143     1293        2        0
# 6        7    2010       7     1143     1293        0        0
# 7        8    2010       7     1143     1293        0        0
#
#    ElapsedSeconds  EventTeamID  EventPlayerID   EventType
# 3              10         1143         600581   miss2_lay
# 4              10         1143         600581     reb_off
# 5              14         1143         600581  made2_jump
# 6              36         1293         602791  miss2_jump
# 7              36         1293         602781     reb_off

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 15]

New_Event.groupby("EventType").size().plot(kind='barh')

# %%
New_Event = (New_Event >> 
     mutate(Turnovers = X.EventType == 'turnover'))

# %%
New_Event.head(10)
# Out:
#     EventID  Season  DayNum  WTeamID  LTeamID  WPoints  LPoints  \
# 3         4    2010       7     1143     1293        0        0
# 4         5    2010       7     1143     1293        0        0
# 5         6    2010       7     1143     1293        2        0
# 6         7    2010       7     1143     1293        0        0
# 7         8    2010       7     1143     1293        0        0
# 8         9    2010       7     1143     1293        2        2
# 9        10    2010       7     1143     1293        0        0
# 10       11    2010       7     1143     1293        4        2
# 11       12    2010       7     1143     1293        0        0
# 12       13    2010       7     1143     1293        4        5
#
#     ElapsedSeconds  EventTeamID  EventPlayerID   EventType  Turnovers
# 3               10         1143         600581   miss2_lay      False
# 4               10         1143         600581     reb_off      False
# 5               14         1143         600581  made2_jump      False
# 6               36         1293         602791  miss2_jump      False
# 7               36         1293         602781     reb_off      False
# 8               40         1293         602781  made2_jump      False
# 9               56         1143         600577      assist      False
# 10              56         1143         600581  made2_jump      False
# 11              72         1293         602791      assist      False
# 12              72         1293         602787  made3_jump      False

# %%
Win_Nums = (New_Event >> 
             group_by(X.WTeamID, X.Season) >>
             summarize(Possessions = X.EventType.count(),
                        Turnovers = X.Turnovers.sum()))

# %%
Win_Nums.head(5)
# Out:
#    WTeamID  Season  Possessions  Turnovers
# 0     1102    2010         2134        192
# 1     1103    2010         6871        656
# 2     1104    2010         5064        468
# 3     1105    2010         2716        278
# 4     1106    2010         3986        420

# %%
Lose_Nums = (New_Event >> 
             group_by(X.LTeamID, X.Season) >>
             summarize(Possessions = X.EventType.count(),
                        Turnovers = X.Turnovers.sum()))

# %%
Lose_Nums.tail(150)
# Out:
#      LTeamID  Season  Possessions  Turnovers
# 196     1311    2010         4999        535
# 197     1312    2010         6351        620
# 198     1313    2010         5981        599
# 199     1314    2010         4943        425
# 200     1315    2010         6396        642
# 201     1316    2010         5245        510
# 202     1317    2010         2653        241
# 203     1318    2010         3630        344
# 204     1319    2010         4104        399
# 205     1320    2010         1295        107
# 206     1321    2010         3734        267
# 207     1322    2010         6072        565
# 208     1323    2010         3506        238
# 209     1324    2010         2807        248
# 210     1325    2010         4686        425
# 211     1326    2010         1647        143
# 212     1328    2010         5167        411
# 213     1329    2010         3230        277
# 214     1330    2010         2504        246
# 215     1331    2010         3842        358
# 216     1332    2010         4652        433
# 217     1333    2010         4988        524
# 218     1334    2010         3025        263
# 219     1335    2010         6286        636
# 220     1336    2010         5124        393
# 221     1337    2010         6830        573
# 222     1338    2010         2509        183
# 223     1339    2010         3154        276
# 224     1340    2010         5665        493
# 225     1341    2010         4277        414
# ..       ...     ...          ...        ...
# 316     1433    2010         2704        225
# 317     1434    2010         4667        417
# 318     1435    2010         2381        207
# 319     1436    2010         3149        308
# 320     1437    2010         2442        212
# 321     1438    2010         4522        367
# 322     1439    2010         2810        260
# 323     1440    2010         7057        594
# 324     1441    2010         3748        361
# 325     1442    2010         4738        410
# 326     1443    2010         3701        320
# 327     1444    2010         4456        405
# 328     1447    2010         7088        725
# 329     1448    2010         3528        299
# 330     1449    2010         3009        294
# 331     1450    2010         4489        440
# 332     1451    2010         3260        311
# 333     1452    2010         1808        141
# 334     1453    2010         3422        310
# 335     1454    2010         3887        322
# 336     1455    2010         2711        271
# 337     1456    2010         3167        252
# 338     1457    2010         4203        394
# 339     1458    2010         2107        172
# 340     1459    2010         2400        199
# 341     1460    2010         3160        333
# 342     1461    2010         5650        549
# 343     1462    2010         2611        227
# 344     1463    2010         5816        530
# 345     1464    2010         6532        624
#
# [150 rows x 4 columns]

# %%
Teams = pd.read_csv("/Users/ericenglin/Desktop/Data Science Club/DataFiles/Teams.csv")

# %%
Teams.head()
# Out:
#    TeamID     TeamName  FirstD1Season  LastD1Season
# 0    1101  Abilene Chr           2014          2019
# 1    1102    Air Force           1985          2019
# 2    1103        Akron           1985          2019
# 3    1104      Alabama           1985          2019
# 4    1105  Alabama A&M           2000          2019

# %%
Players = pd.read_csv("/Users/ericenglin/Desktop/Data Science Club/DataFiles/PlayByPlay_2010/Players_2010.csv")

# %%
Players.head()
# Out:
#    PlayerID  Season  TeamID        PlayerName
# 0    600001    2010    1102     BOHANNON_ZACH
# 1    600002    2010    1102   BRAKEVILLE_ADAM
# 2    600003    2010    1102  BROEKHUIS_TAYLOR
# 3    600004    2010    1102      BROOKS_DEREK
# 4    600005    2010    1102       EL-AMIN_SAJ

# %%
Season_Results = pd.read_csv("/Users/ericenglin/Desktop/Data Science Club/DataFiles/RegularSeasonDetailedResults.csv")

# %%
Season_Results.tail()
# Out:
#        Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 82036    2018     132     1153      56     1222      55    N      0    20
# 82037    2018     132     1172      58     1348      57    N      0    19
# 82038    2018     132     1209      74     1426      61    N      0    25
# 82039    2018     132     1246      77     1397      72    N      0    25
# 82040    2018     132     1335      68     1217      65    N      0    24
#
#        WFGA  WFGM3  WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF
# 75%       17.000000     16.000000      9.000000      5.000000     20.000000
# max       40.000000     33.000000     26.000000     21.000000     41.000000
#
#                LFGM          LFGA        LFGM3         LFGA3          LFTM  \
# count  82041.000000  82041.000000  82041.00000  82041.000000  82041.000000
# mean      22.537146     56.286796      5.99744     19.337539     12.209468
# std        4.387217      7.706462      2.76101      5.896804      5.372825
# min        6.000000     26.000000      0.00000      1.000000      0.000000
# 25%       20.000000     51.000000      4.00000     15.000000      8.000000
# 50%       22.000000     56.000000      6.00000     19.000000     12.000000
# 75%       25.000000     61.000000      8.00000     23.000000     16.000000
# max       47.000000    106.000000     22.00000     58.000000     42.000000
#
#                LFTA           LOR           LDR          LAst           LTO  \
# count  82041.000000  82041.000000  82041.000000  82041.000000  82041.000000
# mean      18.094258     11.188247     21.534257     11.434831     14.358418
# std        7.154317      4.211062      4.529824      3.732018      4.421789
# min        0.000000      0.000000      4.000000      0.000000      0.000000
# 25%       13.000000      8.000000     18.000000      9.000000     11.000000
# 50%       18.000000     11.000000     21.000000     11.000000     14.000000
# 75%       23.000000     14.000000     24.000000     14.000000     17.000000
# max       61.000000     36.000000     49.000000     31.000000     41.000000
#
#                LStl          LBlk           LPF
# count  82041.000000  82041.000000  82041.000000
# mean       6.026304      2.870845     19.827172
# std        2.770446      2.040549      4.527265
# min        0.000000      0.000000      4.000000
# 25%        4.000000      1.000000     17.000000
# 50%        6.000000      3.000000     20.000000
# 75%        8.000000      4.000000     23.000000
# max       22.000000     18.000000     45.000000

# %%
Season_Results['TeamID']=Season_Results['WTeamID']
Season_Results= pd.merge(Season_Results, Teams, on='TeamID')

Season_Results.head(5)
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      18     1104      82     1106      56    H      0    24    49
# 2    2003      21     1104      80     1292      65    H      0    27    59
# 3    2003      25     1104      54     1326      48    N      0    16    57
# 4    2003      29     1104      89     1422      61    H      0    34    70
#
#    WFGM3  WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  LFGM  LFGA  \
# 0      3     14    11    18   14   24    13   23     7     1   22    22    53
# 1     10     20    24    34   12   26    13   13     7     3   14    19    55
# 2      8     24    18    23   10   24    16   13    10     6   13    25    66
# 3      7     25    15    21   17   26    12   13     6     6   21    16    50
# 4      9     22    12    15   16   30    16   10    10     4   17    23    61
#
#    LFGM3  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF  TeamId  \
# 0      2     10    16    22   10   22     8   18     9     2   20    1104
# 1      8     21    10    12   11   18     8   15     6     2   22    1104
# 2      7     23     8    10   17   25    11   21     6     2   20    1104
# 3      2      6    14    22   10   27    12   13     3     5   19    1104
# 4      7     18     8    14   11   21    11   13     2     3   15    1104
#
#    TeamID TeamName  FirstD1Season  LastD1Season
# 0    1104  Alabama           1985          2019
# 1    1104  Alabama           1985          2019
# 2    1104  Alabama           1985          2019
# 3    1104  Alabama           1985          2019
# 4    1104  Alabama           1985          2019

# %%
Win = Season_Results.groupby(["TeamName","Season"]).sum()

# %%
type(Win)
# Out:
# pandas.core.frame.DataFrame
