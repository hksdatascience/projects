# %% [markdown]
# ### Predictive policing
#     - Load data. Clean up.
#     - Exploratory plots. Select features.
#     - Fit predictive model

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load data, cleanup and select some columns we think are important

# %%
#Load daytasets
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# All the cleaning steps are put inside this function, so that we can apply it both to the test and train dataset without writing twice.
def clean_dataset(df):
    """
    Function for cleaning 'train' and 'test' datasets by the same procedure.
    returns:
        df (pandas DataFrame) a clean version of the input df.
    """
    if 'Resolution' in df.columns:
        df = df.loc[df.Resolution.isin(['ARREST, BOOKED', 'ARREST, CITED'])]

    df.loc[:, 'Dates'] = df['Dates'].astype('datetime64[ns]')
    df['formatted_date'] = [d.date() for d in df['Dates']]
    df['formatted_time'] = [d.time() for d in df['Dates']]

    # Extract month, dat, etc
    df['Year'] = [x.year for x in df['formatted_date']]
    df['Month'] = [x.month for x in df['formatted_date']]
    # df['Day'] = [x.day for x in df['formatted_date']]
    df['Hour'] = [x.hour for x in df['formatted_time']]

    day_dict = {'Wednesday': 3, 'Tuesday': 2, 'Monday':1, 'Sunday':7 , 'Saturday':6, 'Friday':5,
           'Thursday':4}
    df['weekday_no'] = df['DayOfWeek'].map(day_dict)

    df = df.drop(['Descript', 'DayOfWeek', 'Dates', 'formatted_date', 'formatted_time', 'Address'], axis = 1, errors = 'ignore')

    return df

# Example:
train = clean_dataset(train)
test = clean_dataset(test)

# %%
# This is what we get after this step
train.head()
# Out:
#           Category PdDistrict      Resolution           X          Y  Year  \
# 0         WARRANTS   NORTHERN  ARREST, BOOKED -122.425892  37.774599  2015
# 1   OTHER OFFENSES   NORTHERN  ARREST, BOOKED -122.425892  37.774599  2015
# 2   OTHER OFFENSES   NORTHERN  ARREST, BOOKED -122.424363  37.800414  2015
# 18  OTHER OFFENSES    BAYVIEW  ARREST, BOOKED -122.386401  37.738983  2015
# 31    NON-CRIMINAL    MISSION  ARREST, BOOKED -122.435150  37.761760  2015
#
#     Month  Hour  weekday_no
# 0       5    23           3
# 1       5    23           3
# 2       5    23           3
# 18      5    21           3
# 31      5    20           3

# %%
# Tell the most common crimes
most_common = train['Category'].value_counts().head(6).index
most_common
# Out:
# Index([u'OTHER OFFENSES', u'DRUG/NARCOTIC', u'WARRANTS', u'ASSAULT',
#        u'LARCENY/THEFT', u'PROSTITUTION'],
#       dtype='object')

# %%
# Count most common crimes by day of the week and time. 
# Groupby is very useful for this!
counts_data = train.loc[train.Category.isin(most_common)].groupby(['Category', 'weekday_no', 'Hour']).count()[['Y']].unstack(0)['Y']
counts_data.head()
# Out:
# Category         ASSAULT  DRUG/NARCOTIC  LARCENY/THEFT  OTHER OFFENSES  \
# weekday_no Hour
# 1          0       207.0          213.0           35.0           542.0
#            1       144.0          139.0           24.0           364.0
#            2       128.0           92.0           24.0           351.0
#            3        70.0           64.0           12.0           229.0
#            4        46.0           60.0           11.0           173.0
#
# Category         PROSTITUTION  WARRANTS
# weekday_no Hour
# 1          0             38.0     206.0
#            1             30.0     166.0
#            2             23.0     127.0
#            3             25.0      87.0
#            4             14.0      96.0

# %%
# For example lets do a fancy table showing the times of the week when something happens more often.
# Here the unstack methos converts a long dataframe (as the one above) to a rectangular table.

table = counts_data.unstack()
table = table[[most_common[0]]]

import seaborn as sns
cm = sns.light_palette("green", as_cmap=True)
s = table.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col1 {
#             background-color:  #dcfadc;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col2 {
#             background-color:  #72bf72;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col3 {
#             background-color:  #60b560;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col4 {
#             background-color:  #56af56;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col5 {
#             background-color:  #c3ecc3;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col6 {
#             background-color:  #198e19;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col7 {
#             background-color:  #45a645;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col8 {
#             background-color:  #5eb45e;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col9 {
#             background-color:  #7fc67f;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col10 {
#             background-color:  #60b560;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col11 {
#             background-color:  #6ebd6e;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col12 {
#             background-color:  #75c175;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col13 {
#             background-color:  #69ba69;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col14 {
#             background-color:  #45a645;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col15 {
#             background-color:  #7ac47a;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col16 {
#             background-color:  #8bcd8b;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col17 {
#             background-color:  #c4edc4;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col18 {
#             background-color:  #a8dda8;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col19 {
#             background-color:  #b6e5b6;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col20 {
#             background-color:  #e5ffe5;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col21 {
#             background-color:  #d8f8d8;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col22 {
#             background-color:  #e5ffe5;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row0_col23 {
#             background-color:  #c5edc5;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col0 {
#             background-color:  #a8dda8;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col2 {
#             background-color:  #abdfab;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col3 {
#             background-color:  #3ba13b;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col4 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col5 {
#             background-color:  #359d35;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col6 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col7 {
#             background-color:  #369e36;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col8 {
#             background-color:  #1f911f;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col9 {
#             background-color:  #2b982b;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col10 {
#             background-color:  #2c982c;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col11 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col12 {
#             background-color:  #299729;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col13 {
#             background-color:  #54ae54;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col14 {
#             background-color:  #46a746;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col15 {
#             background-color:  #58b158;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col16 {
#             background-color:  #47a747;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col17 {
#             background-color:  #4daa4d;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col18 {
#             background-color:  #7bc47b;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col19 {
#             background-color:  #0a850a;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col20 {
#             background-color:  #a7dda7;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col21 {
#             background-color:  #c6eec6;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col22 {
#             background-color:  #e5ffe5;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row1_col23 {
#             background-color:  #d3f5d3;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col0 {
#             background-color:  #e0fce0;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col1 {
#             background-color:  #e1fde1;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col3 {
#             background-color:  #59b159;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col4 {
#             background-color:  #7ac47a;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col5 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col6 {
#             background-color:  #51ad51;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col7 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col8 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col9 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col10 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col11 {
#             background-color:  #229322;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col12 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col13 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col14 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col15 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col16 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col17 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col18 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col19 {
#             background-color:  #008000;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col20 {
#             background-color:  #4daa4d;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col21 {
#             background-color:  #b9e7b9;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col22 {
#             background-color:  #b8e6b8;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row2_col23 {
#             background-color:  #caf0ca;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row3_col0 {
#             background-color:  #bee9be;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row3_col1 {
#             background-color:  #bbe8bb;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row3_col2 {
#             background-color:  #bce8bc;
#         }    #T_d2a2e9ae_e874_11e8_a5ca_5ce0c5892623row3_col3 {
#             background-color:  #aadeaa;
#         }    #T_d2a2e9ae_e874_11e8_a5

# %% [markdown]
# # Fit a model

# %%
# For example, this is sklearn Random Forest, but almost any sklearn model takes an (X, y) in this same way. 
# So you can use X, y with your model.
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

X_train = train[['X', 'Y', 'Year', 'Month', 'Hour', 'weekday_no']].values
y_train = train['Category'].values

clf = RandomForestClassifier(n_estimators=100, max_depth=2,
                             random_state=0)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
from sklearn.metrics import log_loss

print(clf.feature_importances_) # See feature importance (works for regresion trees)
# print(log_loss(y_train, clf.predict(X_train))) #works only if outcome is a number, not a 'text'
# Out:
# [ 0.25127921  0.5033029   0.09498806  0.          0.13769173  0.0127381 ]

# %%
train['predicted_category'] = clf.predict(X_train)

#Print number of correct predictions...
print((train['Category'] == train['predicted_category']).sum())
# number of mistakes...
print((train['Category'] != train['predicted_category']).sum())
# and what if I predicted random?
train['random'] = train['Category'].sample(frac = 1).values
print((train['Category'] == train['random']).sum())
# Out:
# 88489
# 194918
# 45591
