# %%
# Notebook done by Eric Englin with the Data Science Club
# This dataset comes from the DonorsChoose.org Application Screening Challenge
# Found at: https://www.kaggle.com/c/donorschoose-application-screening


import pandas as pd
train = pd.read_csv(r"/Users/ericenglin/Desktop/Data Science Club/Data/Donors Choose Screen/train.csv")

# %%
train.head()
# Out:
#         id                        teacher_id teacher_prefix school_state  \
# 0  p036502  484aaf11257089a66cfedc9461c6bd0a            Ms.           NV
# 1  p039565  df72a3ba8089423fa8a94be88060f6ed           Mrs.           GA
# 2  p233823  a9b876a9252e08a55e3d894150f75ba3            Ms.           UT
# 3  p185307  525fdbb6ec7f538a48beebaa0a51b24f            Mr.           NC
# 4  p013780  a63b5547a7239eae4c1872670848e61a            Mr.           CA
#
#   project_submitted_datetime project_grade_category  \
# 0        2016-11-18 14:45:59          Grades PreK-2
# 1        2017-04-26 15:57:28             Grades 3-5
# 2        2017-01-01 22:57:44             Grades 3-5
# 3        2016-08-12 15:42:11             Grades 3-5
# 4        2016-08-06 09:09:11             Grades 6-8
#
#             project_subject_categories  \
# 0                  Literacy & Language
# 1    Music & The Arts, Health & Sports
# 2  Math & Science, Literacy & Language
# 3                      Health & Sports
# 4                      Health & Sports
#
#             project_subject_subcategories  \
# 0                                Literacy
# 1            Performing Arts, Team Sports
# 2  Applied Sciences, Literature & Writing
# 3                       Health & Wellness
# 4                       Health & Wellness
#
#                                        project_title  \
# 0                           Super Sight Word Centers
# 1                             Keep Calm and Dance On
# 2                              Lets 3Doodle to Learn
# 3  \"Kid Inspired\" Equipment to Increase Activit...
# 4   We need clean water for our culinary arts class!
#
#                                      project_essay_1  \
# 0  Most of my kindergarten students come from low...
# 1  Our elementary school is a culturally rich sch...
# 2  Hello;\r\nMy name is Mrs. Brotherton. I teach ...
# 3  My students are the greatest students but are ...
# 4  My students are athletes and students who are ...
#
#                                      project_essay_2 project_essay_3  \
# 0  I currently have a differentiated sight word c...             NaN
# 1  We strive to provide our diverse population of...             NaN
# 2  We are looking to add some 3Doodler to our cla...             NaN
# 3  The student's project which is totally \"kid-i...             NaN
# 4  For some reason in our kitchen the water comes...             NaN
#
#   project_essay_4                           project_resource_summary  \
# 0             NaN  My students need 6 Ipod Nano's to create and d...
# 1             NaN  My students need matching shirts to wear for d...
# 2             NaN  My students need the 3doodler. We are an SEM s...
# 3             NaN  My students need balls and other activity equi...
# 4             NaN  My students need a water filtration system for...
#
#    teacher_number_of_previously_posted_projects  project_is_approved
# 0                                            26                    1
# 1                                             1                    0
# 2                                             5                    1
# 3                                            16                    0
# 4                                            42                    1

# %%
train[['project_is_approved']].groupby(train['project_is_approved']).agg(['mean', 'count'])
# Out:
#                     project_is_approved
#                                    mean   count
# project_is_approved
# 0                                     0   27734
# 1                                     1  154346

# %%
train.shape
# Out:
# (182080, 16)

# %%
# For our predictive model to be worth anything, we'll need to predict more than 84.7% correctly
# Because we could get 84.7% correct just by predicting that every project will be approved

154346/182080 #84.7%
# Out:
# 0.8476823374340949

# %%
train.project_grade_category.unique()
# Out:
# array(['Grades PreK-2', 'Grades 3-5', 'Grades 6-8', 'Grades 9-12'],
#       dtype=object)

# %%
train[['project_is_approved']].groupby(train['project_subject_categories']).agg(['mean', 'count'])
# Out:
#                                            project_is_approved
#                                                           mean  count
# project_subject_categories
# Applied Learning                                      0.814897   6310
# Applied Learning, Health & Sports                     0.813360   1018
# Applied Learning, History & Civics                    0.795380    303
# Applied Learning, Literacy & Language                 0.861208   3725
# Applied Learning, Math & Science                      0.803624   1711
# Applied Learning, Music & The Arts                    0.809831   1241
# Applied Learning, Special Needs                       0.811769   2481
# Applied Learning, Warmth, Care & Hunger               0.636364     22
# Health & Sports                                       0.846794  16951
# Health & Sports, Applied Learning                     0.851852    297
# Health & Sports, History & Civics                     0.820896     67
# Health & Sports, Literacy & Language                  0.847859   1308
# Health & Sports, Math & Science                       0.848936    470
# Health & Sports, Music & The Arts                     0.782443    262
# Health & Sports, Special Needs                        0.861064   2368
# Health & Sports, Warmth, Care & Hunger                0.903226     31
# History & Civics                                      0.831974   3065
# History & Civics, Applied Learning                    0.753846     65
# History & Civics, Health & Sports                     0.900000     20
# History & Civics, Literacy & Language                 0.885490   2288
# History & Civics, Math & Science                      0.853333    525
# History & Civics, Music & The Arts                    0.821691    544
# History & Civics, Special Needs                       0.815348    417
# History & Civics, Warmth, Care & Hunger               0.000000      1
# Literacy & Language                                   0.869858  39257
# Literacy & Language, Applied Learning                 0.859345   1038
# Literacy & Language, Health & Sports                  0.771654    127
# Literacy & Language, History & Civics                 0.890494   1315
# Literacy & Language, Math & Science                   0.867219  24499
# Literacy & Language, Music & The Arts                 0.838777   2878
# Literacy & Language, Special Needs                    0.854450   6685
# Literacy & Language, Warmth, Care & Hunger            0.840000     25
# Math & Science                                        0.821082  28555
# Math & Science, Applied Learning                      0.832448   2071
# Math & Science, Health & Sports                       0.780488    697
# Math & Science, History & Civics                      0.858326   1087
# Math & Science, Literacy & Language                   0.861046   3843
# Math & Science, Music & The Arts                      0.827961   2761
# Math & Science, Special Needs                         0.825581   3010
# Math & Science, Warmth, Care & Hunger                 0.631579     19
# Music & The Arts                                      0.850006   8527
# Music & The Arts, Applied Learning                    0.714286     21
# Music & The Arts, Health & Sports                     0.656250     32
# Music & The Arts, History & Civics                    0.793103     29
# Music & The Arts, Special Needs                       0.863830    235
# Music & The Arts, Warmth, Care & Hunger               0.666667      3
# Special Needs                                         0.809483   7065
# Special Needs, Health & Sports                        0.765625     64
# Special Needs, Music & The Arts                       0.827255    521
# Special Needs, Warmth, Care & Hunger                  0.771429     35
# Warmth, Care & Hunger                                 0.921953   2191

# %%
len(train.index)
# Out:
# 182080

# %%
# Bringing in resources dataset 

resources = pd.read_csv(r"/Users/ericenglin/Desktop/Data Science Club/Data/Donors Choose Screen/resources.csv")

# %%
resources.head()
# Out:
#         id                                        description  quantity  \
# 0  p233245  LC652 - Lakeshore Double-Space Mobile Drying Rack         1
# 1  p069063        Bouncy Bands for Desks (Blue support pipes)         3
# 2  p069063  Cory Stories: A Kid's Book About Living With Adhd         1
# 3  p069063  Dixon Ticonderoga Wood-Cased #2 HB Pencils, Bo...         2
# 4  p069063  EDUCATIONAL INSIGHTS FLUORESCENT LIGHT FILTERS...         3
#
#     price
# 0  149.00
# 1   14.95
# 2    8.45
# 3   13.59
# 4   24.95

# %%
len(resources.index)
# Out:
# 1541272

# %%
# Want to aggregate this dataset so that we can join it with the training dataset

resource_new = resources.groupby(['id']).agg({
    'quantity':sum,
    'id':["count"],
    'price':sum})

resource_new.columns = ['total requested items', 'different items requests','cost requested']
resource_new.head()
# Out:
#          total requested items  different items requests  cost requested
# id
# p000001                      7                         4          459.56
# p000002                     21                        14          515.89
# p000003                      4                         4          298.97
# p000004                     98                        95         1113.69
# p000005                      8                         4          485.99

# %%
# Quality check
resource_new.describe()
# Out:
#        total requested items  different items requests  cost requested
# count          260115.000000             260115.000000   260115.000000
# mean               16.949515                  5.925348      297.950077
# std                26.353225                  8.324707      368.754986
# min                 1.000000                  1.000000        0.660000
# 25%                 4.000000                  1.000000      104.745000
# 50%                 9.000000                  3.000000      206.020000
# 75%                21.000000                  7.000000      379.640000
# max               930.000000                100.000000     9999.000000

# %%
# Bring out id column so that we can join with the training dataset
# Data Note: Resources has info with both training and unknown test dataset, so we just want the training id's
resource_new['id'] = resource_new.index
resource_new.tail()
# Out:
#          total requested items  different items requests  cost requested  \
# id
# p260111                     27                        27          176.08
# p260112                      6                         2           39.79
# p260113                      3                         3          811.49
# p260114                     39                        10          222.56
# p260115                      2                         2          318.97
#
#               id
# id
# p260111  p260111
# p260112  p260112
# p260113  p260113
# p260114  p260114
# p260115  p260115

# %%
merge_train = pd.merge(train, resource_new, on='id') #merge on id
merge_train.head(100)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3267: FutureWarning: 'id' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          id                        teacher_id teacher_prefix school_state  \
# 0   p036502  484aaf11257089a66cfedc9461c6bd0a            Ms.           NV
# 1   p039565  df72a3ba8089423fa8a94be88060f6ed           Mrs.           GA
# 2   p233823  a9b876a9252e08a55e3d894150f75ba3            Ms.           UT
# 3   p185307  525fdbb6ec7f538a48beebaa0a51b24f            Mr.           NC
# 4   p013780  a63b5547a7239eae4c1872670848e61a            Mr.           CA
# 5   p063374  403c6783e9286e51ab318fba40f8d729           Mrs.           DE
# 6   p103285  4e156c5fb3eea2531601c8736f3751a7           Mrs.           MO
# 7   p181781  c71f2ef13b4bc91afac61ca8fd4c0f9f           Mrs.           SC
# 8   p114989  b580c11b1497a0a67317763b7f03eb27            Ms.           IN
# 9   p191410  2071fb0af994f8f16e7c6ed0f35062a1           Mrs.           IL
# 10  p030093  b9e731e16ad8669f37a43e5316518106        Teacher           VA
# 11  p226941  103cc1667cf9361bf1c58c8425e76e95           Mrs.           CA
# 12  p225747  4681d60136ea859084ab488f2254b219            Ms.           PA
# 13  p173555  9b7f355e34bc9ca5740779b69ee14d8e           Mrs.           NY
# 14  p055350  882c8ddea1d5c4c31976e34f20b461f9            Ms.           FL
# 15  p060293  74c7a7de62df6005b718dfea1447c745           Mrs.           NJ
# 16  p199435  d69e412550b14dd8286e347f726908c2            Mr.           TX
# 17  p074849  5d710e545d6952a3c12bfb45a7f9f08c           Mrs.           IN
# 18  p232007  e7a8f866e3174a77ffe37323f032a8ac           Mrs.           FL
# 19  p037127  b21174f6246deadc11c2157a958d7953           Mrs.           LA
# 20  p230221  3bfe21c62feb8fd744a696a36487b452           Mrs.           PA
# 21  p116615  b3593a375f2cf7fd4469b928ffac1c95           Mrs.           NY
# 22  p106275  4ee410ea0ea8a0b4660b56c2f3648bbf            Ms.           NC
# 23  p070918  a22774168d7910adce6969c8d8faee7c            Mr.           TX
# 24  p144291  fdf9938d5f9e381630384c2452b159e0           Mrs.           PA
# 25  p116102  efc95ee511efe14d1955789663317432           Mrs.           NC
# 26  p070029  b74b266d6e52c0348a8dcef8b0ea4a2b           Mrs.           NJ
# 27  p107356  f4594111d55f22ee3ed5e8e4a1c2852b            Ms.           UT
# 28  p031939  32a2fb6f6a1aca27a686cea452973f03            Mr.           ID
# 29  p044085  65f5f57c7b035d58ec095602a8f7dcf6           Mrs.           OH
# ..      ...                               ...            ...          ...
# 70  p100203  ae538de782db957f784d0eb2abf1aec3            Ms.           FL
# 71  p216335  06ac5121c71ac3a4aae34a8ee59e75ab            Ms.           WI
# 72  p215118  24e1f07552982b0b7d1c6d6a8b08773e           Mrs.           MN
# 73  p123326  e765872bf5c5045c159b757583b33ca3            Ms.           CA
# 74  p216043  720e58234cad163b74c21be2f2d23491        Teacher           MO
# 75  p190639  1921ac6e9b66c4d58140536b793f2ad2           Mrs.           GA
# 76  p035608  e61641cad6c7fe389446286ab58d675a            Ms.           GA
# 77  p194533  9530ab8a78448791d133d13b2c7c11d1           Mrs.           MI
# 78  p005330  280182b5719d5acc7aeb4304af3df65e            Ms.           IL
# 79  p217173  9f936ea91f1a712eeea368f99a383268           Mrs.           OK
# 80  p243195  1f3721218beb28b4831e0446c0500a7b           Mrs.           AL
# 81  p204162  eb4c09521349cf8313bd719fc2b9f3db           Mrs.           CA
# 82  p088899  9b58caab6f7c442566ee1eb22148a1c6           Mrs.           SC
# 83  p218286  a894f9627757603938ebb2b54c54267b           Mrs.           NY
# 84  p024688  2537c362d86a9b84f05f1b360aa11ff1           Mrs.           SC
# 85  p148544  f02b76b46bf631d23826e5e82452268e            Ms.           CT
# 86  p061723  a47b48b4fe9ed4a0259bede1eeec2471           Mrs.           NC
# 87  p062414  d02a6876dee2ab709295b00bd3920859           Mrs.           CA
# 88  p150704  969fdff9e00f9cd7c30ef522668fa0d0            Ms.           NY
# 89  p064902  0361569c8fe6988d4f64c4804844e60c            Mr.           MI
# 90  p160114  d523f258b55bb41c3bcb6dd67cfab6c1            Ms.           OK
# 91  p054727  15f3f3e4d1adff4a1ba433f10f4bd00f            Mr.           CA
# 92  p233164  62801a90e159f464ec8602f634086934            Ms.           MA
# 93  p164497  2e4b1f7df9cc1271efa5210f675bde26            Ms.           FL
# 94  p164688  2bcdc75056a431aae98d6fac11f67787           Mrs.           NY
# 95  p226536  eeecbb6a721708dfb24364160054d2d2            Ms.           CA
# 96  p037347  1e7ee59a8fbf3d9a2f5b96c587eed2ea           Mrs.           TX
# 97  p052732  1f684e6e2dad5985ab688f8c4be8a1a8            Ms.           TN
# 98  p254241  dff0c29b7f57fb2f7b18a10869e2cb73           Mrs.           PA
# 99  p041330  d6a2723a203c70ed75050e0ee07c8635        Teacher           MO
#
#    project_submitted_datetime project_grade_category  \
# 0         2016-11-18 14:45:59          Grades PreK-2
# 1         2017-04-26 15:57:28             Grades 3-5
# 2         2017-01-01 22:57:44             Grades 3-5
# 3         2016-08-12 15:42:11             Grades 3-5
# 4         2016-08-06 09:09:11             Grades 6-8
# 5         2016-11-05 10:01:51          Grades PreK-2
# 6         2016-08-31 00:30:43          Grades PreK-2
# 7         2016-08-03 13:26:01          Grades PreK-2
# 8         2016-09-13 22:35:57             Grades 6-8
# 9         2016-09-24 18:38:59          Grades PreK-2
# 10        2017-03-09 17:16:13          Grades PreK-2
# 11        2016-09-05 19:28:32          Grades PreK-2
# 12        2016-12-08 13:25:03             Grades 3-5
# 13        2016-11-15 22:13:39             Grades 3-5
# 14        2017-02-02 13:46:56          Grades PreK-2
# 15        2016-11-18 18:03:06             Grades 3-5
# 16        2016-09-04 22:48:49          Grades PreK-2
# 17        2017-01-25 22:08:09          Grades PreK-2
# 18        2016-04-27 09:58:04          Grades PreK-2
# 19        2016-05-21 19:46:06          Grades PreK-2
# 20        2016-08-19 21:46:42             Grades 6-8
# 21        2016-09-30 08:12:37          Grades PreK-2
# 22        2016-07-17 21:54:21          Grades PreK-2
# 23        2016-06-16 14:27:56          Grades PreK-2
# 24        2016-10-22 22:25:32          Grades PreK-2
# 25        2016-08-28 21:20:57             Grades 6-8
# 26        2017-01-13 17:40:30          Grades PreK-2
# 27        2016-10-11 19:16:18             Grades 3-5
# 28        2016-10-31 19:17:04            Grades 9-12
# 29        2016-10-25 12:37:57          Grades PreK-2
# ..                        ...                    ...
# 70        2016-09-01 06:47:28             Grades 3-5
# 71        2016-12-21 14:03:07             Grades 6-8
# 72        2017-03-23 12:32:49             Grades 3-5
# 73        2016-05-26 19:31:05             Grades 3-5
# 74        2017-04-18 16:37:31          Grades PreK-2
# 75        2016-07-22 23:19:49             Grades 3-5
# 76        2016-12-12 15:05:29             Grades 3-5
# 77        2016-08-07 13:14:15          Grades PreK-2
# 78        2016-08-26 08:08:54          Grades PreK-2
# 79        2016-10-15 13:42:20             Grades 3-5
# 80        2016-08-24 15:55:15             Grades 3-5
# 81        2017-02-22 17:44:13          Grades PreK-2
# 82        2016-12-08 11:12:19             Grades 3-5
# 83        2017-01-23 21:05:28             Grades 3-5
# 84        2016-06-08 20:50:12            Grades 9-12
# 85        2017-02-28 08:52:03          Grades PreK-2
# 86        2016-08-18 13:43:25          Grades PreK-2
# 87        2016-05-20 01:37:45          Grades PreK-2
# 88        2016-06-20 13:24:34             Grades 3-5
# 89        2016-07-21 17:11:21             Grades 3-5
# 90        2016-09-22 01:14:50          Grades PreK-2
# 91        2016-08-14 03:50:37            Grades 9-12
# 92        2017-02-09 10:42:05          Grades PreK-2
# 93        2017-02-01 12:47:06             Grades 6-8
# 94        2016-12-02 07:43:55             Grades 6-8
# 95        2016-05-26 00:53:26          Grades PreK-2
# 96        2016-09-21 18:06:04          Grades PreK-2
# 97        2016-10-28 13:57:51          Grades PreK-2
# 98        2016-05-26 12:01:28          Grades PreK-2
# 99        2017-01-12 11:28:24             Grades 6-8
#
#                project_subject_categories  \
# 0                     Literacy & Language
# 1       Music & The Arts, Health & Sports
# 2     Math & Science, Literacy & Language
# 3                         Health & Sports
# 4                         Health & Sports
# 5   Applied Learning, Literacy & Language
# 6                         Health & Sports
# 7   Applied Learning, Literacy & Language
# 8                          Math & Science
# 9                     Literacy & Language
# 10    Literacy & Language, Math & Science
# 11    Literacy & Language, Math & Science
# 12  Applied Learning, Literacy & Language
# 13                    Literacy & Language
# 14                          Special Needs
# 15    Literacy & Language, Math & Science
# 16    Literacy & Language, Math & Science
# 17                         Math & Science
# 18  Applied Learning, Literacy & Language
# 19        Applied Learning, Special Needs
# 20                         Math & Science
# 21     Applied Learning, Music & The Arts
# 22                    Literacy & Language
# 23    Literacy & Language, Math & Science
# 24                    Literacy & Language
# 25          Math & Science, Special Needs
# 26    Literacy & Language, Math & Science
# 27    Math & Science, Literacy & Language
# 28                    Literacy & Language
# 29                    Literacy & Language
# ..                                    ...
# 70                         Math & Science
# 71                    Literacy & Language
# 72                         Math & Science
# 73                    Literacy & Language
# 74                       Music & The Arts
# 75    Literacy & Language, Math & Science
# 76                    Literacy & Language
# 77                         Math & Science
# 78                          Special Needs
# 79                    Literacy & Language
# 80                    Literacy & Language
# 81                         Math & Science
# 82          Math & Science, Special Needs
# 83      Health & Sports, Applied Learning
# 84                         Math & Science
# 85    Literacy & Language, Math & Science
# 86                         Math & Science
# 87                       Applied Learning
# 88                         Math & Science
# 89                        Health & Sports
# 90     Literacy & Language, Special Needs
# 91                        Health & Sports
# 92                    Literacy & Language
# 93                         Math & Science
# 94     Literacy & Language, Special Needs
# 95                          Special Needs
# 96    Literacy & Language, Math & Science
# 97                    Literacy & Language
# 98    Literacy & Language, Math & Science
# 99                    Literacy & Language
#
#                   project_subject_subcategories  \
# 0                                      Literacy
# 1                  Performing Arts, Team Sports
# 2        Applied Sciences, Literature & Writing
# 3                             Health & Wellness
# 4                             Health & Wellness
# 5     Character Education, Literature & Writing
# 6                             Health & Wellness
# 7       Early Development, Literature & Writing
# 8                                   Mathematics
# 9                                      Literacy
# 10            Literature & Writing, Mathematics
# 11                        Literacy, Mathematics
# 12                Character Education, Literacy
# 13                         Literature & Writing
# 14                                Special Needs
# 15                        Literacy, Mathematics
# 16                             ESL, Mathematics
# 17           Health & Life Science, Mathematics
# 18  College & Career Prep, Literature & Writing
# 19             Early Development, Special Needs
# 20                             Applied Sciences
# 21           Early Development, Performing Arts
# 22                                     Literacy
# 23            Literature & Writing, Mathematics
# 24                                     Literacy
# 25                   Mathematics, Special Needs
# 26                        Literacy, Mathematics
# 27  Environmental Science, Literature & Writing
# 28                         Literature & Writing
# 29                                     Literacy
# ..                                          ...
# 70                Applied Sciences, Mathematics
# 71                                     Literacy
# 72                             Applied Sciences
# 73               Literacy, Literature & Writing
# 74                                  Visual Arts
# 75                        Literacy, Mathematics
# 76                    ESL, Literature & Writing
# 77                Applied Sciences, Mathematics
# 78                                Special Needs
# 79                                     Literacy
# 80                                     Literacy
# 81                        Environmental Science
# 82                   Mathematics, Special Needs
# 83        Health & Wellness, Parent Involvement
# 84                                  Mathematics
# 85                        Literacy, Mathematics
# 86                                  Mathematics
# 87           Early Development, Extracurricular
# 88                Applied Sciences, Mathematics
# 89                            Health & Wellness
# 90                      Literacy, Special Needs
# 91                   Gym & Fitness, Team Sports
# 92                                ESL, Literacy
# 93                             Applied Sciences
# 94                      Literacy, Special Needs
# 95                                Special Needs
# 96            Literature & Writing, Mathematics
# 97               Literacy, Literature & Writing
# 98                        Literacy, Mathematics
# 99                    ESL, Literature & Writing
#
#                                         project_title  \
# 0                            Super Sight Word Centers
# 1                              Keep Calm and Dance On
# 2                               Lets 3Doodle to Learn
# 3   \"Kid Inspired\" Equipment to Increase Activit...
# 4    We need clean water for our culinary arts class!
# 5               Need to Reach Our Virtual  Mentors!!!
# 6                               Active Kindergartners
# 7                Fabulous Firsties-Wiggling to Learn!
# 8               Wobble Chairs Help Fidgety Kids Focus
# 9                         Snuggle Up With A Good Book
# 10                         Writing, Writing, Writing!
# 11                                  Technology Boost!
# 12                      Life Lessons through Literacy
# 13  Extra! Extra! Read all about it!!  We love to ...
# 14                                   Flexible seating
# 15                                      A Comfy Seat!
# 16                      iPads for Bilingual Education
# 17          Taking Learning Outside of the Classroom!
# 18                                Watch Readers Grow!
# 19                         Success With Communication
# 20              A-Maze-ing Problem Solving Strategies
# 21  Oral Language Development through the use of p...
# 22             \r\nABC Ya in the Library!\r\n\r\n\r\n
# 23               Mini Devices With Many Opportunities
# 24                Leveled Library for Little Learners
# 25  Balance Ball Seating Needed for Engaging Group...
# 26                       No Paper And Pencils Allowed
# 27                               Can you hear me now?
# 28                Finding a Voice Through Literarture
# 29                                       Let Me Read!
# ..                                                ...
# 70                          Teaching with Technology!
# 71                            Calling All Chromebooks
# 72                              Indoor Recess Rescue!
# 73                Making Books Accessible to Everyone
# 74                                 Artistic Computing
# 75         Flexible Seating for Personalized Learning
# 76  Reading games for more comprehensive reading f...
# 77  STEM Learning for Science, Technology, Enginee...
# 78  Help Provide Access to Education for Children ...
# 79                      Forever Fabulous In Fifth!!!!
# 80             An Apple a Day Keeps Illiteracy at Bay
# 81                                    Save our Planet
# 82                                Learning in ACTION!
# 83       QR Codes...Empowering Parents As PE Partners
# 84          Bouncing Straight to the Top of the Class
# 85                                        Let's Play!
# 86             Experiencing Numbers with Unifix Cubes
# 87                Back to School With A Backpack Cart
# 88                                 Print & Let's Go!!
# 89                            \"Is This Seat Taken?\"
# 90                            Bring Our Story to Life
# 91      Striped Shirts To Ref Our Youth League!!!\r\n
# 92                                 Reading Rockstars!
# 93                          Reality, Well...Virtually
# 94                                 TOON Graphic Books
# 95  Learning To Sit is Crucial to Learning and Att...
# 96                          Wibble, Wobble, and Work!
# 97                Writers Growing...Learners Glowing!
# 98               Kindergarten! Little Minds in Bloom!
# 99  Expand Learning Through Flexible Seating*\r\n\r\n
#
#                                       project_essay_1  \
# 0   Most of my kindergarten students come from low...
# 1   Our elementary school is a culturally rich sch...
# 2   Hello;\r\nMy name is Mrs. Brotherton. I teach ...
# 3   My students are the greatest students but are ...
# 4   My students are athletes and students who are ...
# 5   My kids tell me each day that they want to mak...
# 6   Kindergarten is the new first grade. My studen...
# 7   First graders are fantastic! They are excited ...
# 8   My seventh graders dream big. They can't wait ...
# 9   I teach first grade in a small farming town in...
# 10  My classroom has 24 students in it. We have an...
# 11  My children come to school everyday with the s...
# 12  My school is located in a high poverty area, j...
# 13  Each day my fifth graders walk into our \"home...
# 14  The children at our school come from a variety...
# 15  My third graders are eager to learn new concep...
# 16  My students are Hispanics, Spanish been their ...
# 17  \"Learning is an active process. We learn by d...
# 18  During our reading workshop students are at da...
# 19  A preschool classroom, created to meet the nee...
# 20  As a teacher in a low-income/high poverty scho...
# 21  Teaching kindergarten in a diverse district po...
# 22  My mostly Spanish speaking kindergarten studen...
# 23  \"You can dream, create, design, and build the...
# 24  My students attend a K-8 school in an impoveri...
# 25  As a teacher in a low-income/high poverty scho...
# 26  I work in a low-income, high poverty school di...
# 27  Our classroom is filled with bright smiles and...
# 28  My students live in a growing school district ...
# 29  We have the best students ever! We are a commu...
# ..                                                ...
# 70  My students are young impressionable kids who ...
# 71  My students are 100% Latino, mostly Puerto Ric...
# 72  We are in a rural area with a high number of f...
# 73  My students are special because they don't let...
# 74  Our students at Osceola are from a small rural...
# 75  My fourth grade students are eager to learn an...
# 76  My students walk into my classroom every morni...
# 77  Welcome to a our learning world.  We are a low...
# 78  My students absolutely love learning. They wal...
# 79  This year I am thrilled to be teaching 3 class...
# 80  As a teacher in a low-income/high poverty scho...
# 81  The students in my class are all English langu...
# 82  My students all face different educational dif...
# 83  \"Free the child's potential, and you will tra...
# 84  The students at my school are pioneers. They c...
# 85  My students are creative, hardworking, and hav...
# 86  I teach second grade at an inner-city school. ...
# 87  My future kindergarten students are sure to be...
# 88  My students are full with energy and prefer to...
# 89  My students attend 5th grade in an intermediat...
# 90  The students at my school are multicultural, c...
# 91  The students of our school are poor. Most of o...
# 92  Welcome to English as a Second Language! My st...
# 93  Our school is located in northeast Florida. We...
# 94  My students are smart, motivated, and caring k...
# 95  My Students are Preschool Autism kiddios, who ...
# 96  I have 22 active 5 and 6 year old students in ...
# 97  I am so privileged to do what I love everyday!...
# 98  The students in my kindergarten class are hard...
# 99  We are the home of the \"Tigers\", a strong, d...
#
#                                       project_essay_2  \
# 0   I currently have a differentiated sight word c...
# 1   We strive to provide our diverse population of...
# 2   We are looking to add some 3Doodler to our cla...
# 3   The student's project which is totally \"kid-i...
# 4   For some reason in our kitchen the water comes...
# 5   I started a program called Telementoring in ho...
# 6   With balance discs and stools as flexible seat...
# 7   First graders love learning! We need 6 wiggle-...
# 8   I have used alternative seating in my classroo...
# 9   There is nothing better than snuggling up with...
# 10  In our classroom, we use dry erase boards thro...
# 11  With our new iPads, my students will be able t...
# 12  As a Reading Specialist who serves Grades 1-8 ...
# 13  My students have had a taste of good reading! ...
# 14  After fifteen years of teaching, we have seen ...
# 15  My students will use these cushions on a daily...
# 16  Having an iPad pro will allow my students lear...
# 17  We are constantly learning in kindergarten. Ev...
# 18  My students lack confidence. I have a class wi...
# 19  When my students enter my classroom for the fi...
# 20  The Gravity Maze game incorporates the STEM sk...
# 21  Students don't often get the chance to 'play' ...
# 22  With this leveled classroom library, these stu...
# 23  I plan on implementing these iPads into readin...
# 24  This year, we are really focusing on reaching ...
# 25  My students are in school for eight hours. Tha...
# 26  The activities that I have chosen will not onl...
# 27  Chromebooks computers are used daily in our cl...
# 28  My students are voracious readers, hungrily po...
# 29  My students need Graphic Novels of high intere...
# ..                                                ...
# 70  Technology in the classroom has become a vital...
# 71  My students are in desperate need of computers...
# 72  We are limited as to what we can do in our cla...
# 73  One of the biggest obstacles I face as a teach...
# 74  Chrome books will enhance creative learning fo...
# 75  Flexible seating will create a comfortable, in...
# 76  My students need games and activities that foc...
# 77  Having this set of STEM (science, technology, ...
# 78  My students love learning. They love coming to...
# 79  What an awesome blessing it will be to have my...
# 80  Having the iPads and laptop will allow for dif...
# 81  My students will be learning about recycling a...
# 82  My classroom is equipped with a projector and ...
# 83  One of the greatest challenges to getting my s...
# 84  Students in high school are offered less oppor...
# 85  My students love playing games, and will work ...
# 86  I have received a training on math education a...
# 87  Our school is located in a low income area.  A...
# 88  I am in desperate need of ink for my class. I ...
# 89  Flexible classrooms give students a choice in ...
# 90  My students struggle with writing.  Sometimes ...
# 91  Our students love basketball and to helping ou...
# 92  The Fiction and Nonfiction Readers will help m...
# 93  The create your won virtual maze will help my ...
# 94  I am requesting a set of TOON graphic books to...
# 95  My students are learning to sit and I want to ...
# 96  My students need flexible seating so that they...
# 97  There are many things that a teacher uses dail...
# 98  Our class is requesting an IPad to enhance lea...
# 99  Our school values the individuality and learni...
#
#                                       project_essay_3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  During our reading workshop. We do mini lesson...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                       project_essay_4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Your donations would greatly be a blessing for...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                              project_resource_summary  \
# 0   My students need 6 Ipod Nano's to create and d...
# 1   My students need matching shirts to wear for d...
# 2   My students need the 3doodler. We are an SEM s...
# 3   My students need balls and other activity equi...
# 4   My students need a water filtration system for...
# 5   My students need tablets  in order to communic...
# 6   My students need stability stools and inflatab...
# 7   My students need wiggle stools to allow them t...
# 8   My students need seating that allows the most ...
# 9   My students need 2 youth sized reclining chair...
# 10  My students need individual dry erase boards t...
# 11  My students need a projector and tablets to al...
# 12  My students need books that teach life lessons...
# 13  My students need good books, with life lessons...
# 14  My students need flexible seating options to p...
# 15  My students need cushions to sit on during cen...
# 16  My students need to learn how to use technolog...
# 17  My students need engaging math and science hom...
# 18  My students need these reading materials to he...
# 19  My students need manipulatives to pieces to gi...
# 20  My students need opportunities to increase the...
# 21  My students need the opportunity to develop or...
# 22  My students need a leveled classroom library! ...
# 23  My students need four iPad minis, and four pro...
# 24  My students need leveled readers to maximize t...
# 25  My students need balance ball chairs for the g...
# 26  My students need hands -on education to help t...
# 27  My students need earbud headphones to use in t...
# 28  My students need 80 copies of \"The House of t...
# 29  My students need Graphic Novels of high intere...
# ..                                                ...
# 70  My students need iPads to further integrate te...
# 71  My students need computers in our classroom in...
# 72  My students need some creative tools for indoo...
# 73  My students need portable CD players to listen...
# 74  My students need chrome books to be able to re...
# 75  My students need flexible seating options to p...
# 76  My students need games for comprehension and l...
# 77  My students need the STEM bundle to build a le...
# 78  My students need hammers, magnets, and tweezer...
# 79  My students need a Scholastic Magazine subscri...
# 80  My students need the 2 Apple  IPads mini to ta...
# 81  My students need iPads and accessories to help...
# 82  My students need an interactive whiteboard sys...
# 83  My students need kindle fire tablets, screen p...
# 84  My students need Stay-n-Play Balance Balls and...
# 85  My students need new educational games that wi...
# 86  My students need experiences with math manipul...
# 87  My students need a mobile backpack storage car...
# 88  My students need ink. This will lessen their d...
# 89  My students need flexible seating options in t...
# 90  My students need a printer, ink and paper.  Th...
# 91  My students need 16 Striped referee jerseys to...
# 92  My students need both fiction and nonfiction r...
# 93  My students need the Seedling Design your Own ...
# 94  My students need 10 prize winning TOON graphic...
# 95  My students need the cube chair to help increa...
# 96  My students need flexible seating so that they...
# 97  My students need access to a dry erase board t...
# 98  My students need an IPad to support academic a...
# 99  My students need flexible and comfortable seat...
#
#     teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                             26                    1
# 1                                              1                    0
# 2                                              5                    1
# 3                                             16                    0
# 4                                             42                    1
# 5                                              0                    1
# 6                                              1                    1
# 7                                              0                    1
# 8                                             13                    1
# 9                                             12                    1
# 10                                             1                    1
# 11                                             1                    1
# 12                                             3                    1
# 13                                             5                    0
# 14                                             0                    1
# 15                                            11                    1
# 16                                             3                    1
# 17                                            64                    1
# 18                                             6                    1
# 19                                            34                    0
# 20                                             0                    1
# 21                                             0                    1
# 22                                             5                    1
# 23                                             0                    1
# 24                                             8                    1
# 25                                            28                    1
# 26                                             3                    1
# 27                                             6                    1
# 28                                             0                    1
# 29                                             1                    1
# ..                                           ...                  ...
# 70                                             0                    1
# 71                                             2                    1
# 72                                             0                    0
# 73                                             4                    1
# 74                                             0                    1
# 75                                             2                    1
# 76                                             1                    1
# 77                                             3                    1
# 78                                             2                    0
# 79                                            12                    1
# 80                                             1                    1
# 81                                            23                    1
# 82                                             2                    1
# 83                                           151                    1
# 84                                             0                    1
# 85                                             5                    1
# 86                                             1                    1
# 87                                            72                    1
# 88                                             7                    1
# 89                                             5                    1
# 90                                             0                    1
# 91                                            18                    1
# 92                                             7                    1
# 93                                             4                    0
# 94                                            77                    1
# 95                                             1                    1
# 96                                             2                    1
# 97                                             0                    1
# 98                                             0                    1
# 99                                             1                    0
#
#     total requested items  different items requests  cost requested
# 0                       6                         2          299.98
# 1                      20                         1           20.00
# 2                       1                         1          469.99
# 3                       5                         5          684.47
# 4                       2                         1          355.50
# 5                       7                         2          207.82
# 6                       6                         2          111.00
# 7                       6                         1           69.13
# 8                       4                         1           79.95
# 9                       2                         1           59.88
# 10                     30                         1            3.40
# 11                      3                         2          563.97
# 12                     18                        18          176.59
# 13                    143                         7           42.53
# 14                      5                         3          234.40
# 15                      2                         1           55.00
# 16                      2                         2          699.98
# 17                     19                        15          714.38
# 18                      5                         5          467.97
# 19                     13                        10          272.90
# 20                     10                         2           50.56
# 21                      3                         3          299.99
# 22                      2                         2         1248.00
# 23                      8                         5         1326.31
# 24                     13                        12          262.46
# 25                      6                         2          119.96
# 26                     10                         9          431.92
# 27                     90                         1            1.39
# 28                     80                         1            8.02
# 29                     20                         2           10.20
# ..                    ...                       ...             ...
# 70                     10                         3          299.47
# 71                     10                         2          333.91
# 72                     13                         4          195.94
# 73                     11                         1           32.00
# 74                      5                         1          167.02
# 75                     13                         4          138.43
# 76                      2                         2          178.99
# 77                      2                         2          318.20
# 78                      7                         7          190.44
# 79                     56                        15          137.13
# 80                      3                         2          501.17
# 81                      8                         3          574.47
# 82                      1                         1          169.00
# 83                     10                         8          597.91
# 84                     20                         2           33.93
# 85                     11                         9          126.60
# 86                      3                         2           98.37
# 87                      1                         1          199.00
# 88                      5                         1           58.73
# 89                      6                         1           59.88
# 90                      6                         5          371.00
# 91                     16                         4           75.80
# 92                      8                         2           79.00
# 93                      3                         1           51.76
# 94                      1                         1          126.66
# 95                      4                         1          199.50
# 96                     22                         1           59.49
# 97                     17                         2          284.66
# 98                      1                         1          384.00
# 99                      4                         2          411.78
#
# [100 rows x 19 columns]

# %%
merge_train.describe()
# Out:
#        teacher_number_of_previously_posted_projects  project_is_approved  \
# count                                 182080.000000        182080.000000
# mean                                      11.237055             0.847682
# std                                       28.016086             0.359330
# min                                        0.000000             0.000000
# 25%                                        0.000000             1.000000
# 50%                                        2.000000             1.000000
# 75%                                        9.000000             1.000000
# max                                      451.000000             1.000000
#
#        total requested items  different items requests  cost requested
# count          182080.000000             182080.000000   182080.000000
# mean               16.971447                  5.941509      297.731304
# std                26.241957                  8.349074      366.718002
# min                 1.000000                  1.000000        0.660000
# 25%                 4.000000                  1.000000      104.480000
# 50%                 9.000000                  3.000000      205.980000
# 75%                21.000000                  7.000000      379.000000
# max               930.000000                100.000000     9999.000000

# %%
merge_train.to_csv('merge_train.csv')

# %%
# Now that we have our dataset together, we want to do some more exploratory data analysis
# First area of exploration: Those that post a lot tend to request less for each post

import matplotlib.pyplot  as plt
plt.scatter(merge_train['teacher_number_of_previously_posted_projects'],merge_train['cost requested'])
plt.title('EDA Graph 1')
plt.xlabel('Number of Previously Posted Projects')
plt.ylabel('Cost Requested')
plt.show()

# %%
# We have 4 quantitative fields that may predict for a project getting approved
# Want to check if these are correlated with eachother

import seaborn as sb

sb.heatmap(merge_train.corr())  
plt.title('EDA Graph 2: Correlation Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(merge_train['project_is_approved'])
plt.title("EDA Graph 3")
plt.show()

# %%
# Now want to eyeball test the how related project_is_approved is with our 4 fields

merge_train.groupby("project_is_approved").mean()
# Out:
#                      teacher_number_of_previously_posted_projects  \
# project_is_approved
# 0                                                        6.902791
# 1                                                       12.015867
#
#                      total requested items  different items requests  \
# project_is_approved
# 0                                20.261592                  8.098796
# 1                                16.380250                  5.553872
#
#                      cost requested
# project_is_approved
# 0                        357.596003
# 1                        286.974384

# %%
# Wondering whether it makes sense to make the project grade categories into dummy variables
# Looks like we could include this but doesn't seem like it makes a major difference between different grade groups

merge_train.groupby("project_grade_category").mean()
# Out:
#                         teacher_number_of_previously_posted_projects  \
# project_grade_category
# Grades 3-5                                                 10.440615
# Grades 6-8                                                 10.762209
# Grades 9-12                                                 9.519742
# Grades PreK-2                                              12.508689
#
#                         project_is_approved  total requested items  \
# project_grade_category
# Grades 3-5                         0.853977              17.423073
# Grades 6-8                         0.843459              21.359187
# Grades 9-12                        0.835236              22.288078
# Grades PreK-2                      0.847124              13.602504
#
#                         different items requests  cost requested
# project_grade_category
# Grades 3-5                              5.772786      281.504519
# Grades 6-8                              5.761109      291.319098
# Grades 9-12                             5.616842      339.286663
# Grades PreK-2                           6.231655      303.426058

# %%
merge_train['cost requested']= merge_train['cost requested'].astype('int64')
merge_train['project_is_approved']= merge_train['project_is_approved'].astype('int64')

# %%
import numpy as np
from sklearn.model_selection import train_test_split

cols=['total requested items','different items requests',
      'teacher_number_of_previously_posted_projects', 'cost requested'] 


merge_train2 = merge_train[cols]

y=merge_train['project_is_approved']
X_train, X_test, y_train, y_test = train_test_split(merge_train2, y, test_size=0.3)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (127456, 4) (127456,)
# (54624, 4) (54624,)

# %%
X_train.dtypes
# Out:
# total requested items                           int64
# different items requests                        int64
# teacher_number_of_previously_posted_projects    int64
# cost requested                                  int64
# dtype: object

# %%
y_train.describe()
# Out:
# count    127456.000000
# mean          0.848010
# std           0.359012
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: project_is_approved, dtype: float64

# %%
import statsmodels.api as sm
logit_model=sm.Logit(y_train, X_train)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.514216
#          Iterations 7
#                                        Results: Logit
# =============================================================================================
# Model:                      Logit                       Pseudo R-squared:         -0.207
# Dependent Variable:         project_is_approved         AIC:                      131087.7968
# Date:                       2019-02-20 21:15            BIC:                      131126.8189
# No. Observations:           127456                      Log-Likelihood:           -65540.
# Df Model:                   3                           LL-Null:                  -54315.
# Df Residuals:               127452                      LLR p-value:              1.0000
# Converged:                  1.0000                      Scale:                    1.0000
# No. Iterations:             7.0000
# ---------------------------------------------------------------------------------------------
#                                               Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ---------------------------------------------------------------------------------------------
# total requested items                         0.0255   0.0005  52.9562 0.0000  0.0246  0.0265
# different items requests                     -0.0230   0.0012 -19.9629 0.0000 -0.0253 -0.0207
# teacher_number_of_previously_posted_projects  0.0429   0.0008  56.5114 0.0000  0.0414  0.0444
# cost requested                                0.0022   0.0000  78.9250 0.0000  0.0021  0.0023
# =============================================================================================

# %%
X_train.isnull().values.any()
y_train.isnull().values.any()
# Out:
# False

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.3f}'.format(logreg.score(X_test, y_test))) #85%
# Out:
# Accuracy of logistic regression classifier on test set: 0.846

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[   27  8296]
#  [   93 46208]]

# %%
(27 + 46208)/(27 + 46208 + 8296 + 93)
# Out:
# 0.8464228178090216

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.23      0.00      0.01      8323
#            1       0.85      1.00      0.92     46301
#
#    micro avg       0.85      0.85      0.85     54624
#    macro avg       0.54      0.50      0.46     54624
# weighted avg       0.75      0.85      0.78     54624

# %%
# ROC curve
# We want this curve to hit the upper left hand corner
# Very bad if it is hitting the dotted red line because that means our predictions aren't worth much at all! 

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# # How'd We Do?

# %% [markdown]
# #### Not great! We would actually be better off just approving every applicant that sends in a request. This means that we need to think more about why certain applicants are being turned down because we are not getting that information covered in our model yet!
#
#
# ### Questions to Explore Further
#  <br>
#  <li> <em>Teacher Prefix</em>: Do the Mr's get all the donations? </li>
#  <li> <em>State</em>: Do all of the donors are from California and want to donate locally?</li>
#  <li> <em>Essay Responses</em>: Can we look at reading level to pick out the non-approved projects?</li>
#  <li> <em>Project Categories</em>: Are there certain categories that almost never get approved?</li>
#  <li> <em>Model Type</em>: Is there a better type of model to use here? Maybe random forest?</li>

# %%
# Teacher prefix EDA
df_agg1 = train[['project_is_approved']].groupby(train['teacher_prefix']).agg(['mean', 'count'])
df_agg1.sort_values([('project_is_approved', 'count')],ascending=False)

# Data caveat: 
# Because we are making 2 columns in aggregation, we get a multi index
# To sort this, we need to contain the tuple describing the column inside a list
# You do this by closing the 2 fields, project_is_approved & mean, within a set of parentheses
# Out:
#                project_is_approved
#                               mean  count
# teacher_prefix
# Mrs.                      0.854085  95405
# Ms.                       0.843052  65066
# Mr.                       0.842022  17667
# Teacher                   0.794223   3912
# Dr.                       0.807692     26

# %%
x1 = df_agg1[('project_is_approved', 'count')]
y1 = df_agg1[('project_is_approved', 'mean')]
plt.scatter(x1,y1)
plt.title("EDA Graph 4")
plt.show()

# %%
#State EDA

df_agg2 = train[['project_is_approved']].groupby(train['school_state'], sort=False).agg(['mean', 'count'])
df_agg2 = df_agg2.sort_values([('project_is_approved', 'count')],ascending=False)
df_agg2.head(15)
# Out:
#              project_is_approved
#                             mean  count
# school_state
# CA                      0.856431  25695
# TX                      0.815670  12304
# NY                      0.853582  12157
# FL                      0.824500  10359
# NC                      0.853480   8463
# IL                      0.853792   7332
# GA                      0.834087   6636
# SC                      0.864923   6463
# MI                      0.844478   5324
# PA                      0.852543   5093
# IN                      0.847937   4314
# MO                      0.857547   4247
# OH                      0.871467   4139
# MA                      0.860138   4054
# LA                      0.834009   3946

# %%
df_agg2new= df_agg2[df_agg2[('project_is_approved', 'count')] > 2500]

x2 = df_agg2new[('project_is_approved', 'count')]
y2 = df_agg2new[('project_is_approved', 'mean')]
plt.scatter(x2,y2)
plt.title("EDA Graph 5")
plt.show()

# %%
# Project category EDA

df_agg3 = train[['project_is_approved']].groupby(train['project_subject_categories']).agg(['mean', 'count'])
df_agg3 = df_agg3.sort_values([('project_is_approved', 'count')],ascending=False)
df_agg3.head(15)
# Out:
#                                       project_is_approved
#                                                      mean  count
# project_subject_categories
# Literacy & Language                              0.869858  39257
# Math & Science                                   0.821082  28555
# Literacy & Language, Math & Science              0.867219  24499
# Health & Sports                                  0.846794  16951
# Music & The Arts                                 0.850006   8527
# Special Needs                                    0.809483   7065
# Literacy & Language, Special Needs               0.854450   6685
# Applied Learning                                 0.814897   6310
# Math & Science, Literacy & Language              0.861046   3843
# Applied Learning, Literacy & Language            0.861208   3725
# History & Civics                                 0.831974   3065
# Math & Science, Special Needs                    0.825581   3010
# Literacy & Language, Music & The Arts            0.838777   2878
# Math & Science, Music & The Arts                 0.827961   2761
# Applied Learning, Special Needs                  0.811769   2481

# %%
df_agg3new= df_agg3[df_agg3[('project_is_approved', 'count')] > 1000]
x3 = df_agg3new[('project_is_approved', 'count')]
y3 = df_agg3new[('project_is_approved', 'mean')]
plt.scatter(x3,y3)
plt.title("EDA Graph 6")
plt.show()
